# %% [markdown]
# # Fasz kivan

# %%
import pandas as pd
import numpy as np

local_path = '/Users/csizi/Development/marathon_statistics/dataset/csv/bszm_2008_2020/'

bszm = pd.read_csv(local_path + 'bszm_cleaned.csv', encoding = "utf8", 
                    sep=';', header=0)

# %%
bszm.drop(['Category/Placement', 'event_year', '1.day/1.length', '1.day/2.length', '1.day/3.length', '1.day/length', '2.day/1.length', '2.day/2.length', '2.day/3.length', '2.day/length',
           '3.day/1.length', '3.day/2.length', '3.day/3.length', '3.day/length', '4.day/1.length', '4.day/2.length', '4.day/3.length', '4.day/length', 'event_length'], axis = 1, inplace=True)

# %%
bszm.drop(['Name', 'Placement', 'Born', 'Team', 'City', 'Number', '1.day/1.time', '1.day/2.time', '1.day/3.time', '1.day/sum', '2.day/1.time'
           , '2.day/2.time', '2.day/3.time', '2.day/sum', '3.day/1.time', '3.day/2.time', '3.day/3.time', '3.day/sum', '4.day/1.time', '4.day/2.time'
           , '4.day/3.time', '4.day/sum', 'Category', 'Country', 'tempo_category'], axis = 1, inplace=True)

# %%
bszm.drop(['1/1_tempo', '1/2_tempo', '1/3_tempo', '1_tempo', '2/1_tempo', '2/2_tempo', '2/3_tempo', '2_tempo'
           ,'3/1_tempo', '3/2_tempo', '3/3_tempo', '3_tempo'
           , '4/1_tempo', '4/2_tempo', '4/3_tempo', '4_tempo'], axis = 1, inplace=True)

# %%
bszm['Gender'] = pd.get_dummies(bszm['Gender'], drop_first=True)
bszm['finished'] = pd.get_dummies(bszm['finished'], drop_first=True)
bszm['club_member'] = pd.get_dummies(bszm['club_member'], drop_first=True)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.0

# %%
bszm
# Out:
#       Gender   Result  Ran km  finished   age  finisher_result  \
# 0          1  46928.0   196.0         1  43.0          46928.0
# 1          1  47208.0   196.0         1  32.0          47208.0
# 2          1  50735.0   196.0         1  38.0          50735.0
# 3          1  51767.0   196.0         1  34.0          51767.0
# 4          1  52959.0   196.0         1  42.0          52959.0
# ...      ...      ...     ...       ...   ...              ...
# 2501       1  84831.0   195.0         1  43.0          84831.0
# 2502       0  85191.0   195.0         1  42.0          85191.0
# 2503       1  85541.0   195.0         1  45.0          85541.0
# 2504       0  87555.0   195.0         1  24.0          87555.0
# 2505       1  88516.0   195.0         1  59.0          88516.0
#
#       average_tempo(minutes/km)  club_member
# 0                      3.990476            1
# 1                      4.014286            1
# 2                      4.314201            1
# 3                      4.401956            0
# 4                      4.503316            1
# ...                         ...          ...
# 2501                   7.250513            0
# 2502                   7.281282            1
# 2503                   7.311197            0
# 2504                   7.483333            0
# 2505                   7.565470            1
#
# [2506 rows x 8 columns]

# %%
x = bszm
y = bszm['finished']
x.drop(['finished', 'Ran km', 'Result'], axis = 1, inplace=True)
x
# Out:
#       Gender   age  finisher_result  average_tempo(minutes/km)  club_member
# 0          1  43.0          46928.0                   3.990476            1
# 1          1  32.0          47208.0                   4.014286            1
# 2          1  38.0          50735.0                   4.314201            1
# 3          1  34.0          51767.0                   4.401956            0
# 4          1  42.0          52959.0                   4.503316            1
# ...      ...   ...              ...                        ...          ...
# 2501       1  43.0          84831.0                   7.250513            0
# 2502       0  42.0          85191.0                   7.281282            1
# 2503       1  45.0          85541.0                   7.311197            0
# 2504       0  24.0          87555.0                   7.483333            0
# 2505       1  59.0          88516.0                   7.565470            1
#
# [2506 rows x 5 columns]

# %%
tf.random.set_seed(42)

# %%
model_1 = tf.keras.Sequential([tf.keras.layers.Dense(1)])

# %%
x = np.asarray(x).astype('float32')

# %%
model_1.compile(loss = tf.keras.losses.BinaryCrossentropy(), optimizer = tf.keras.optimizers.SGD(), metrics = ['accuracy'])
#SGD stands for Stochastic Gradient Descent

model_1.fit(x, y, epochs = 200)
# Out:
# Epoch 1/200
# 79/79 [==============================] - 0s 807us/step - loss: nan - accuracy: 0.1081
# Epoch 2/200
# 79/79 [==============================] - 0s 789us/step - loss: nan - accuracy: 0.1081
# Epoch 3/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 4/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 5/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 6/200
# 79/79 [==============================] - 0s 996us/step - loss: nan - accuracy: 0.1081
# Epoch 7/200
# 79/79 [==============================] - 0s 917us/step - loss: nan - accuracy: 0.1081
# Epoch 8/200
# 79/79 [==============================] - 0s 787us/step - loss: nan - accuracy: 0.1081
# Epoch 9/200
# 79/79 [==============================] - 0s 909us/step - loss: nan - accuracy: 0.1081
# Epoch 10/200
# 79/79 [==============================] - 0s 825us/step - loss: nan - accuracy: 0.1081
# Epoch 11/200
# 79/79 [==============================] - 0s 991us/step - loss: nan - accuracy: 0.1081
# Epoch 12/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 13/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 14/200
# 79/79 [==============================] - 0s 937us/step - loss: nan - accuracy: 0.1081
# Epoch 15/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 16/200
# 79/79 [==============================] - 0s 892us/step - loss: nan - accuracy: 0.1081
# Epoch 17/200
# 79/79 [==============================] - 0s 792us/step - loss: nan - accuracy: 0.1081
# Epoch 18/200
# 79/79 [==============================] - 0s 817us/step - loss: nan - accuracy: 0.1081
# Epoch 19/200
# 79/79 [==============================] - 0s 778us/step - loss: nan - accuracy: 0.1081
# Epoch 20/200
# 79/79 [==============================] - 0s 769us/step - loss: nan - accuracy: 0.1081
# Epoch 21/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 22/200
# 79/79 [==============================] - 0s 855us/step - loss: nan - accuracy: 0.1081
# Epoch 23/200
# 79/79 [==============================] - 0s 837us/step - loss: nan - accuracy: 0.1081
# Epoch 24/200
# 79/79 [==============================] - 0s 798us/step - loss: nan - accuracy: 0.1081
# Epoch 25/200
# 79/79 [==============================] - 0s 829us/step - loss: nan - accuracy: 0.1081
# Epoch 26/200
# 79/79 [==============================] - 0s 841us/step - loss: nan - accuracy: 0.1081
# Epoch 27/200
# 79/79 [==============================] - 0s 792us/step - loss: nan - accuracy: 0.1081
# Epoch 28/200
# 79/79 [==============================] - 0s 896us/step - loss: nan - accuracy: 0.1081
# Epoch 29/200
# 79/79 [==============================] - 0s 908us/step - loss: nan - accuracy: 0.1081
# Epoch 30/200
# 79/79 [==============================] - 0s 823us/step - loss: nan - accuracy: 0.1081
# Epoch 31/200
# 79/79 [==============================] - 0s 813us/step - loss: nan - accuracy: 0.1081
# Epoch 32/200
# 79/79 [==============================] - 0s 815us/step - loss: nan - accuracy: 0.1081
# Epoch 33/200
# 79/79 [==============================] - 0s 796us/step - loss: nan - accuracy: 0.1081
# Epoch 34/200
# 79/79 [==============================] - 0s 811us/step - loss: nan - accuracy: 0.1081
# Epoch 35/200
# 79/79 [==============================] - 0s 856us/step - loss: nan - accuracy: 0.1081
# Epoch 36/200
# 79/79 [==============================] - 0s 845us/step - loss: nan - accuracy: 0.1081
# Epoch 37/200
# 79/79 [==============================] - 0s 953us/step - loss: nan - accuracy: 0.1081
# Epoch 38/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 39/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 40/200
# 79/79 [==============================] - 0s 764us/step - loss: nan - accuracy: 0.1081
# Epoch 41/200
# 79/79 [==============================] - 0s 819us/step - loss: nan - accuracy: 0.1081
# Epoch 42/200
# 79/79 [==============================] - 0s 856us/step - loss: nan - accuracy: 0.1081
# Epoch 43/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 44/200
# 79/79 [==============================] - 0s 858us/step - loss: nan - accuracy: 0.1081
# Epoch 45/200
# 79/79 [==============================] - 0s 799us/step - loss: nan - accuracy: 0.1081
# Epoch 46/200
# 79/79 [==============================] - 0s 841us/step - loss: nan - accuracy: 0.1081
# Epoch 47/200
# 79/79 [==============================] - 0s 814us/step - loss: nan - accuracy: 0.1081
# Epoch 48/200
# 79/79 [==============================] - 0s 821us/step - loss: nan - accuracy: 0.1081
# Epoch 49/200
# 79/79 [==============================] - 0s 817us/step - loss: nan - accuracy: 0.1081
# Epoch 50/200
# 79/79 [==============================] - 0s 834us/step - loss: nan - accuracy: 0.1081
# Epoch 51/200
# 79/79 [==============================] - 0s 807us/step - loss: nan - accuracy: 0.1081
# Epoch 52/200
# 79/79 [==============================] - 0s 797us/step - loss: nan - accuracy: 0.1081
# Epoch 53/200
# 79/79 [==============================] - 0s 811us/step - loss: nan - accuracy: 0.1081
# Epoch 54/200
# 79/79 [==============================] - 0s 821us/step - loss: nan - accuracy: 0.1081
# Epoch 55/200
# 79/79 [==============================] - 0s 841us/step - loss: nan - accuracy: 0.1081
# Epoch 56/200
# 79/79 [==============================] - 0s 984us/step - loss: nan - accuracy: 0.1081
# Epoch 57/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 58/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 59/200
# 79/79 [==============================] - 0s 851us/step - loss: nan - accuracy: 0.1081
# Epoch 60/200
# 79/79 [==============================] - 0s 921us/step - loss: nan - accuracy: 0.1081
# Epoch 61/200
# 79/79 [==============================] - 0s 838us/step - loss: nan - accuracy: 0.1081
# Epoch 62/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 63/200
# 79/79 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.1081
# Epoch 64/200
# 79/79 [==============================] - 0s 842us/step - loss: nan - accuracy: 0.1081
# Epoch 65/200
# 79/79 [==============================] - 0s 968us/step - loss: nan - accuracy: 0.1081
# Epoch 66/200
# 79/79 [==============================] - 0s 857us/step - loss: nan - accuracy: 0.1081
# Epoch 67/200
# 79/79 [==============================] - 0s 922us/step - loss: nan - accuracy: 0.1081
# Epoch 68/200
# 79/79 [==============================] - 0s 848us/step - loss: nan - accuracy: 0.1081
# Epoch 69/200
# 79/79 [==============================] - 0s 829us/step - loss: nan - accuracy: 0.1081
# Epoch 70/200
# 79/79 [==============================] - 0s 894us/step - loss: nan - accuracy: 0.1081
# Epoch 71/200
# 79/79 [==============================] - 0s 929us/step - loss: nan - accuracy: 0.1081
# Epoch 72/200
# 79/79 [==============================] - 0s 853us/step - loss: nan - accuracy: 0.1081
# Epoch 73/200
# 79/79 [==============================] - 0s 843us/step - loss: nan - accuracy: 0.1081
# Epoch 74/200
# 79/79 [==============================] - 0s 801us/step - loss: nan - accuracy: 0.1081
# Epoch 75/200
# 79/79 [==============================] - 0s 881us/step - loss: nan - accuracy: 0.1081
# Epoch 76/200
# 79/79 [==============================] - 0s 878us/step - loss: nan - accuracy: 0.1081
# Epoch 77/200
# 79/79 [==============================] - 0s 822us/step - loss: nan - accuracy: 0.1081
# Epoch 78/200
# 79/79 [==============================] - 0s 790us/step - loss: nan - accuracy: 0.1081
# Epoch 79/200
#  1/79 [..............................] - ETA: 0s - loss: nan - accuracy: 0.0938
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/zc/mq862pjx7v34hn0r82tf8_zw0000gn/T/ipykernel_3074/3374676122.py in <module>
#       2 #SGD stands for Stochastic Gradient Descent
#       3
# ----> 4 model_1.fit(x, y, epochs = 200)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1090     """Updates the progbar."""
#    1091     logs = logs or {}
# -> 1092     self._maybe_init_progbar()
#    1093     if self.use_steps:
#    1094       self.seen = batch + 1  # One-indexed.
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/callbacks.py in _maybe_init_progbar(self)
#    1067       # step.
#    1068       self.stateful_metrics = self.stateful_metrics.union(
# -> 1069           set(m.name for m in self.model.metrics))
#    1070
#    1071     if self.progbar is None:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/engine/training.py in metrics(self)
#     713         metrics += self.compiled_metrics.metrics
#     714
# --> 715     for l in self._flatten_layers():
#     716       metrics.extend(l._metrics)  # pylint: disable=protected-access
#     717     return metrics
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/engine/base_layer.py in _flatten_layers(self, recursive, include_self)
#    2937
#    2938   def _flatten_layers(self, recursive=True, include_self=True):
# -> 2939     for m in self._flatten_modules(
#    2940         recursive=recursive, include_self=include_self):
#    2941       if isinstance(m, Layer):
#
# KeyboardInterrupt:
