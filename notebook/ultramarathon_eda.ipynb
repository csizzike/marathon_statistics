# %% [markdown]
# # EDA on cleaned ultramarathon results

# %%
import pandas as pd
import numpy as np
import seaborn as sns

local_path = '/Users/csizi/Development/marathon_statistics/dataset/csv/bszm_2008_2020/'

bszm = pd.read_csv(local_path + 'bszm_cleaned.csv', encoding = "utf8", 
                    sep=';', header=0)

bszm
# Out:
#       Placement                  Name    Born Category Country  \
# 0           1.0         Beda Szabolcs  1977.0       M3     HUN
# 1           2.0           Bódis Tamás  1988.0       M2     HUN
# 2           3.0  Theisinger, Wolfgang  1982.0       M2     GER
# 3           4.0       Strifler Attila  1986.0       M2     HUN
# 4           5.0         Szedlák Csaba  1978.0       M3     HUN
# ...         ...                   ...     ...      ...     ...
# 2501       46.0         Kollár Zoltán  1965.0       M3     HUN
# 2502        5.0   Országné Faragó Éva  1966.0       F3     HUN
# 2503       47.0         Molnár Attila  1963.0       M3     HUN
# 2504        6.0          Hack Zsanett  1984.0       F1     HUN
# 2505       48.0          Maczó András  1949.0       M4     HUN
#
#                            Team           City Gender  Number  \
# 0     ELTE SE Sashegyi gepárdok       Budapest      M   484.0
# 1     ELTE SE Sashegyi gepárdok       Budapest      M   479.0
# 2            RC Abschnitt Mitte     Regenstauf      M   511.0
# 3                             -          Gyula      M   407.0
# 4                  Vitalitás SE       Budapest      M   449.0
# ...                         ...            ...    ...     ...
# 2501                          -       Budapest      M    55.0
# 2502                  Szondi SE      Kecskemét      F    32.0
# 2503                          -      Oroszlány      M    45.0
# 2504                          -  Nyergesújfalu      F    27.0
# 2505                   Futapest       Budapest      M    26.0
#
#      Category/Placement  ...   2_tempo  3/1_tempo  3/2_tempo  3/3_tempo  \
# 0                F3 / 1  ...  3.979836   3.962406   4.100000   3.931298
# 1                F1 / 1  ...  4.165721   3.705514   3.980392   3.924936
# 2                F2 / 1  ...  4.417769   4.223058   4.362745   4.145038
# 3                F1 / 2  ...  4.525520   4.219298   4.365686   4.229008
# 4                F3 / 2  ...  4.546314   4.478697   4.529412   4.655216
# ...                 ...  ...       ...        ...        ...        ...
# 2501           28 (F/3)  ...  7.445810   6.912281   6.961765   7.399491
# 2502            3 (N/3)  ...  7.097669   6.694236   8.759804   9.022901
# 2503           29 (F/3)  ...  7.248897   6.674185   7.541176   8.452926
# 2504            1 (N/1)  ...  7.643352   6.308271   8.311765   8.634860
# 2505           30 (F/3)  ...  7.584121   6.909774   0.000000  17.515267
#
#        3_tempo  4/1_tempo  4/2_tempo  4/3_tempo   4_tempo  tempo_category
# 0     4.006912   3.833333   4.529304   3.649123  4.016346            fast
# 1     3.879416   3.693613   4.411172   3.634503  3.925321            fast
# 2     4.254224   4.154691   4.875458   3.846979  4.305769            fast
# 3     4.279570   4.171657   4.877289   3.949318  4.345513            fast
# 4     4.540323   4.280439   5.017399   4.139376  4.491987            fast
# ...        ...        ...        ...        ...       ...             ...
# 2501  7.078725   6.743513   7.088828   7.702729  7.179808            slow
# 2502  8.206221   6.975050   8.449634   8.411306  7.963462            slow
# 2503  7.550691   6.670659   7.947802   7.855750  7.507372            slow
# 2504  7.795315   6.602794   7.958791   9.010721  7.869231            slow
# 2505  7.404378   7.044910   8.463370   8.311891  7.958013            slow
#
# [2506 rows x 67 columns]

# %%
sns.scatterplot(x='tempo_category', y='average_tempo(minutes/km)', hue='Gender', data=bszm)
# Out:
# <AxesSubplot:xlabel='tempo_category', ylabel='average_tempo(minutes/km)'>

# %%
bszm['tempo_category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='tempo_category'>

# %%
bszm['finished'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='finished'>

# %%
sns.scatterplot(x='age', y='Ran km', hue='Gender', data=bszm)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Ran km'>

# %%
sns.scatterplot(x='average_tempo(minutes/km)', y='age', hue='Gender', data=bszm)
# Out:
# <AxesSubplot:xlabel='average_tempo(minutes/km)', ylabel='age'>

# %%
sns.distplot(bszm['average_tempo(minutes/km)'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='average_tempo(minutes/km)', ylabel='Density'>

# %%
sns.scatterplot(x='average_tempo(minutes/km)', y='', hue='finished', data=bszm)
# Out:
# <AxesSubplot:xlabel='average_tempo(minutes/km)', ylabel='Ran km'>

# %%
#from dataprep.eda import plot, create_report

#report = create_report(bszm)

#report.show_browser()
# Out:
#   0%|          | 0/11232 [00:00<?, ?it/s]
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
